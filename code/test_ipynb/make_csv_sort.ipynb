# %%
# !conda list | grep pandas

# %%
# !conda install pandas -y
# Out:
# Channels:
#  - defaults
# Platform: linux-64
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /data/ephemeral/home/miniconda3/envs/p1
#
#   added / updated specs:
#     - pandas
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     blas-1.0                   |         openblas          46 KB
#     bottleneck-1.3.5           |  py312ha883a20_0         131 KB
#     libgfortran-ng-11.2.0      |       h00389a5_1          20 KB
#     libgfortran5-11.2.0        |       h1234567_1         2.0 MB
#     libopenblas-0.3.21         |       h043d6bf_0         5.4 MB
#     numexpr-2.8.7              |  py312he7dcb8a_0         149 KB
#     numpy-1.26.2               |  py312h2809609_0          10 KB
#     numpy-base-1.26.2          |  py312he1a6c75_0         7.7 MB
#     pandas-2.1.4               |  py312h526ad5a_0        14.7 MB
# ...

# %%
import pandas as pd

# %%
result = pd.read_csv('../submit/20231215_020918_CNN_FM.csv')

# %%
result
# Out:
#        user_id        isbn    rating
# 0        11676  0002005018  7.641480
# 1       116866  0002005018  9.232446
# 2       152827  0060973129  8.867621
# 3       157969  0374157065  8.677981
# 4        67958  0399135782  9.073978
# ...        ...         ...       ...
# 76694   278543  1576734218  6.977098
# 76695   278563  3492223710  7.283370
# 76696   278633  1896095186  6.366011
# 76697   278668  8408044079  2.975823
# 76698   278851  0767907566  5.163552
#
# [76699 rows x 3 columns]
